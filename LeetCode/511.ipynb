# %%
import pandas as pd

# %%
data = [[1, 2, '2016-03-01', 5], [1, 2, '2016-05-02', 6], [2, 3, '2017-06-25', 1], [3, 1, '2016-03-02', 0], [3, 4, '2018-07-03', 5]]
activity = pd.DataFrame(data, columns=['player_id', 'device_id', 'event_date', 'games_played']).astype({'player_id':'Int64', 'device_id':'Int64', 'event_date':'datetime64[ns]', 'games_played':'Int64'})

# %%
activity
# Out:
#    player_id  device_id event_date  games_played
# 0          1          2 2016-03-01             5
# 1          1          2 2016-05-02             6
# 2          2          3 2017-06-25             1
# 3          3          1 2016-03-02             0
# 4          3          4 2018-07-03             5

# %%
activity.event_date = activity.event_date.sort_values()
activity
# Out:
#    player_id  device_id event_date  games_played
# 0          1          2 2016-03-01             5
# 1          1          2 2016-05-02             6
# 2          2          3 2017-06-25             1
# 3          3          1 2016-03-02             0
# 4          3          4 2018-07-03             5

# %%
activity = activity.sort_values(by=['player_id', 'event_date'])
activity
# Out:
#    player_id  device_id event_date  games_played
# 0          1          2 2016-03-01             5
# 1          1          2 2016-05-02             6
# 2          2          3 2017-06-25             1
# 3          3          1 2016-03-02             0
# 4          3          4 2018-07-03             5

# %%
result = activity.groupby('player_id')

# %%
result = result['event_date'].min().reset_index()

# %%
result
# Out:
#    player_id event_date
# 0          1 2016-03-01
# 1          2 2017-06-25
# 2          3 2016-03-02

# %%
result.rename(columns={"event_date":"first_login"}, inplace=True)

# %%
result
# Out:
#    player_id first_login
# 0          1  2016-03-01
# 1          2  2017-06-25
# 2          3  2016-03-02
